# %% [markdown]
# # CS504 Project: Draft Success Analysis Data Collection
#
# There were three different spreadsheets needed:
# 1) Team Draft History
# 2) Historical Team Records (Ws-Ls)
# 3) Individual Player Season Stats with AV Score
#
# All of the data was collected from pro-football-reference.com.
#
# Item 1, because of html oddities, was captured using the data scraping tool Octoparse.
#
# Items 2 and 3 were captured using the Python Pandas library method read_html.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### Team Historical Records

# %%
file = 'Draft_history_Football-links.xlsx'
filedf = pd.read_excel(file,sheet_name='team')
file_list = filedf.values.tolist()
endurl = '#all_team_index'

# %%
#iterate over each team, collect their team success chart, and append it into one dataframe
i = 0
for team_url in file_list:
    beg_url= str(team_url).replace('[','').replace(']','').replace("'",'')
    
    if i == 0:
        
        df1 = pd.read_html(beg_url+endurl)
        df = df1[0]
        i += 1
    
    else:
        
        team_df = pd.read_html(beg_url+endurl)
        df = df.append(team_df[0]) 
        i += 1

# %%
df
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Year                 Lg                 Tm
# 0                2021                NFL  Arizona Cardinals
# 1                2020                NFL  Arizona Cardinals
# 2                2019                NFL  Arizona Cardinals
# 3                2018                NFL  Arizona Cardinals
# 4                2017                NFL  Arizona Cardinals
# ..                ...                ...                ...
# 14               1930                NFL   Brooklyn Dodgers
# 0                1952                NFL      Dallas Texans
# 0                1951                NFL     New York Yanks
# 1                1950                NFL     New York Yanks
# 2                1949                NFL  New York Bulldogs
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                     W                  L                  T
# 0                   7                  1                  0
# 1                   8                  8                  0
# 2                   5                 10                  1
# 3                   3                 13                  0
# 4                   8                  8                  0
# ..                ...                ...                ...
# 14                  7                  4                  1
# 0                   1                 11                  0
# 0                   1                  9                  2
# 1                   7                  5                  0
# 2                   1                 10                  1
#
#    Unnamed: 6_level_0 Unnamed: 7_level_0 Points       ... Def Rank  \
#           Div. Finish           Playoffs     PF   PA  ...      Yds
# 0            1st of 4                NaN    246  138  ...        4
# 1            3rd of 4                NaN    410  367  ...       13
# 2            4th of 4                NaN    361  442  ...       32
# 3            4th of 4                NaN    225  425  ...       20
# 4            3rd of 4                NaN    295  361  ...        6
# ..                ...                ...    ...  ...  ...      ...
# 14          4th of 11                NaN    154   59  ...        1
# 0            6th of 6                NaN    182  427  ...       12
# 0            6th of 6                NaN    241  382  ...       12
# 1            3rd of 7                NaN    366  367  ...       12
# 2            5th of 5                NaN    153  368  ...        9
#
#    Overall Rank                  Simple Rating System
#             T/G Pts± Yds± out of                  MoV   SoS    SRS  OSRS  DSRS
# 0             7    2    5     32                 13.5  -0.3   13.2   6.2   7.0
# 1            17   13   11     32                  2.7  -0.1    2.6   1.5   1.0
# 2            18   23   29     32                 -5.1   1.8   -3.2  -0.3  -2.9
# 3            29   32   32     32                -12.5   1.0  -11.5  -9.6  -1.9
# 4            23   24   15     32                 -4.1   0.4   -3.7  -4.0   0.2
# ..          ...  ...  ...    ...                  ...   ...    ...   ...   ...
# 14            1    3    1     11                  7.9  -2.1    5.8   1.4   4.4
# 0            11   12   12     12                -20.4   2.4  -18.0  -6.0 -12.0
# 0             7   12   12     12                -11.8   2.3   -9.4  -0.9  -8.5
# 1             4    7   11     13                 -0.1  -3.5   -3.6   5.4  -8.9
# 2            10    9   10     10                -17.9   1.3  -16.6  -9.0  -7.5
#
# [2234 rows x 29 columns]

# %%
df.to_excel('team_historical_records.xlsx')

# %% [markdown]
# ### Player Season Data

# %%
file2 = 'team_draft_data.xlsx'
filedf = pd.read_excel(file2,sheet_name='Sheet1')
url_list = filedf.player_link.values.tolist()
names = filedf.name.values.tolist()
names
# Out:
# ['Zaven Collins',
#  'Rondale Moore',
#  'Marco Wilson',
#  'Victor Dimukeje',
#  'Tay Gowan',
#  'James Wiggins',
#  'Michal Menet',
#  'Isaiah Simmons',
#  'Josh Jones',
#  'Leki Fotu',
#  'Rashard Lawrence',
#  'Evan Weaver',
#  'Eno Benjamin',
#  'Kyler Murray',
#  'Byron Murphy',
#  'Andy Isabella',
#  'Zach Allen',
#  'Hakeem Butler',
#  'Deionte Thompson',
#  'KeeSean Johnson',
#  'Lamont Gaillard',
#  'Joshua Miles',
#  'Michael Dogbe',
#  'Caleb Wilson',
#  'Josh Rosen',
#  'Christian Kirk',
#  'Mason Cole',
#  'Chase Edmonds',
#  'Christian Campbell',
#  'Korey Cunningham',
#  'Haason Reddick',
#  'Budda Baker',
#  'Chad Williams',
#  'Dorian Johnson',
#  'Will Holden',
#  'T.J. Logan',
#  'Rudy Ford',
#  'Robert Nkemdiche',
#  'Brandon Williams',
#  'Evan Boehm',
#  'Marqui Christian',
#  'Cole Toner',
#  'Harlan Miller',
#  'D.J. Humphries',
#  'Markus Golden',
#  'David Johnson',
#  'Rodney Gunter',
#  'Shaquille Riddick',
#  'JJ Nelson',
#  'Gerald Christian',
#  'Deone Bucannon',
#  'Troy Niklas',
#  'Kareem Martin',
#  'John Brown',
#  'Logan Thomas',
#  'Ed Stinson',
#  'Walt Powell',
#  'Jonathan Cooper',
#  'Kevin Minter',
#  'Tyrann Mathieu',
#  'Alex Okafor',
#  'Earl Watford',
#  'Stepfan Taylor',
#  'Ryan Swope',
#  'Andre Ellington',
#  'D.C. Jefferson',
#  'Michael Floyd',
#  'Jamell Fleming',
#  'Bobby Massie',
#  'Senio Kelemete',
#  'Justin Bethel',
#  'Ryan Lindley',
#  'Nate Potter',
#  'Patrick Peterson',
#  'Ryan Williams',
#  'Rob Housler',
#  'Sam Acho',
#  'Anthony Sherman',
#  'Quan Sturdivant',
#  'David Carter',
#  'DeMarco Sampson',
#  'Dan Williams',
#  'Daryl Washington',
#  'Andre Roberts',
#  "O'Brien Schofield",
#  'John Skelton',
#  'Jorrick Calvin',
#  'Jim Dray',
#  'Beanie Wells',
#  'Cody Brown',
#  'Rashad Johnson',
#  'Greg Toler',
#  'Herman Johnson',
#  'Will Davis',
#  'LaRod Stephens-Howling',
#  'Trevor Canfield',
#  'Dominique Rodgers-Cromartie',
#  'Calais Campbell',
#  'Early Doucet',
#  'Kenny Iwebema',
#  'Tim Hightower',
#  'Chris Harrington',
#  'Brandon Keith',
#  'Levi Brown',
#  'Alan Branch',
#  'Buster Davis',
#  'Steve Breaston',
#  'Ben Patrick',
#  'Matt Leinart',
#  'Deuce Lutui',
#  'Leonard Pope',
#  'Gabe Watson',
#  'Brandon Johnson',
#  'Jonathan Lewis',
#  'Todd Watkins',
#  'Antrel Rolle',
#  'J.J. Arrington',
#  'Eric Green',
#  'Darryl Blackstock',
#  'Elton Brown',
#  'Lance Mitchell',
#  'LeRon McCoy',
#  'Larry Fitzgerald',
#  'Karlos Dansby',
#  'Darnell Dockett',
#  'Alex Stepanovich',
#  'Antonio Smith',
#  'Nick Leckey',
#  'John Navarre',
#  'Bryant Johnson',
#  'Calvin Pace',
#  'Anquan Boldin',
#  'Gerald Hayes',
#  'Kenny King',
#  'Reggie Wells',
#  'Tony Gilbert',
#  'Wendell Bryant',
#  'Levar Fisher',
#  'Josh McCown',
#  'Dennis Johnson',
#  'Nate Dwyer',
#  'Jason McAddley',
#  'Josh Scobey',
#  'Mike Banks',
#  'Leonard Davis',
#  'Kyle Vanden Bosch',
#  'Michael Stone',
#  'Adrian Wilson',
#  'Bill Gramatica',
#  'Marcus Bell',
#  'Mario Fatafehi',
#  'Bobby Newcombe',
#  'Renaldo Hill',
#  'Tevita Ofahengaue',
#  'Thomas Jones',
#  'Raynoch Thompson',
#  'Darwin Walker',
#  'David Barrett',
#  'Mao Tosi',
#  'Jay Tant',
#  'Jabari Issa',
#  'Sekou Sanyika',
#  'David Boston',
#  'L.J. Shelton',
#  'Johnny Rutledge',
#  'Tom Burke',
#  'Joel Makovicka',
#  'Paris Johnson',
#  'Yusuf Scott',
#  'Coby Rhinehart',
#  'Melvin Bradley',
#  'Dennis McKinley',
#  'Chris Greisen',
#  'Andre Wadsworth',
#  'Corey Chavous',
#  'Anthony Clement',
#  'Michael Pittman',
#  'Terry Hardy',
#  'Zack Walz',
#  'Phil Savoy',
#  'Jomo Cousins',
#  'Pat Tillman',
#  'Ron Janes',
#  'Tom Knight',
#  'Jake Plummer',
#  'Ty Howard',
#  'Chris Dishman',
#  'Chad Carpenter',
#  'Rod Brown',
#  'Tony McCombs',
#  'Mark Smith',
#  'Simeon Rice',
#  'Leeland McElroy',
#  'Johnny McWilliams',
#  'Aaron Graham',
#  'James Dexter',
#  'Harry Stamps',
#  'Dell McGee',
#  'Mike Foley',
#  'Jarius Hayes',
#  'Frank Sanders',
#  'Stoney Case',
#  'Cedric Davis',
#  'Lance Scott',
#  'Tito Paul',
#  'Anthony Bridges',
#  'Billy Williams',
#  'Wesley Leasy',
#  'Chad Eaton',
#  'Jamir Miller',
#  'Chuck Levy',
#  'Rich Braham',
#  'Eric England',
#  'Perry Carter',
#  'John Reece',
#  'Terry Irving',
#  'Anthony Redmon',
#  'Terry Samuels',
#  'Frank Harvey',
#  'Kyle Pitts',
#  'Richie Grant',
#  'Jalen Mayfield',
#  'Darren Hall',
#  'Drew Dalman',
#  "Ta'Quon Graham",
#  'Adetokunbo Ogundeji',
#  'Avery Williams',
#  'Frank Darby',
#  'AJ Terrell',
#  'Marlon Davidson',
#  'Matt Hennessy',
#  'Mykal Walker',
#  'Jaylinn Hawkins',
#  'Sterling Hofrichter',
#  'Chris Lindstrom',
#  'Kaleb McGary',
#  'Kendall Sheffield',
#  'John Cominsky',
#  'Qadree Ollison',
#  'Jordan Miller',
#  'Marcus Green',
#  'Calvin Ridley',
#  'Isaiah Oliver',
#  'Deadrin Senat',
#  'Ito Smith',
#  'Russell Gage',
#  'Foyesade Oluokun',
#  'Takkarist McKinley',
#  'Duke Riley',
#  'Sean Harlow',
#  'Damontae Kazee',
#  'Brian Hill',
#  'Eric Saubert',
#  'Keanu Neal',
#  'Deion Jones',
#  'Austin Hooper',
#  "De'Vondre Campbell",
#  'Wes Schweitzer',
#  'Devin Fuller',
#  'Vic Beasley',
#  'Jalen Collins',
#  'Tevin Coleman',
#  'Justin Hardy',
#  'Grady Jarrett',
#  'Jake Rodgers',
#  'Akeem King',
#  'Jake Matthews',
#  "Ra'Shede Hageman",
#  'Dezmen Southward',
#  'Devonta Freeman',
#  'Prince Shembo',
#  'Ricardo Allen',
#  'Marquis Spruill',
#  'Yawin Smallwood',
#  'Tyler Starr',
#  'Desmond Trufant',
#  'Robert Alford',
#  'Malliciah Goodman',
#  'Levine Toilolo',
#  'Stansly Maponga',
#  'Kemal Ishmael',
#  'Zeke Motta',
#  'Sean Renfree',
#  'Peter Konz',
#  'Lamar Holmes',
#  'Bradie Ewing',
#  'Jonathan Massaquoi',
#  'Charles Mitchell',
#  'Travian Robertson',
#  'Julio Jones',
#  'Akeem Dent',
#  'Jacquizz Rodgers',
#  'Matthew Bosher',
#  'Andrew Jackson',
#  'Cliff Matthews',
#  'Sean Weatherspoon',
#  'Corey Peters',
#  'Mike Johnson',
#  'Joe Hawley',
#  'Dominique Franks',
#  'Kerry Meier',
#  'Shann Schillinger',
#  'Peria Jerry',
#  'William Moore',
#  'Chris Owens',
#  'Lawrence Sidbury',
#  'William Middleton',
#  'Garrett Reynolds',
#  'Spencer Adkins',
#  'Vance Walker',
#  'Matt Ryan',
#  'Sam Baker',
#  'Curtis Lofton',
#  'Chevis Jackson',
#  'Harry Douglas',
#  'Thomas DeCoud',
#  'Robert James',
#  'Kroy Biermann',
#  'Thomas Brown',
#  'Wilrey Fontenot',
#  'Keith Zinger',
#  'Jamaal Anderson',
#  'Justin Blalock',
#  'Chris Houston',
#  'Laurent Robinson',
#  'Stephen Nicholas',
#  'Martrez Milner',
#  'Trey Lewis',
#  'David Irons',
#  'Doug Datish',
#  'Daren Stone',
#  'Jason Snelling',
#  'Jimmy Williams',
#  'Jerious Norwood',
#  'Quinn Ojinnaka',
#  'Adam Jennings',
#  'D.J. Shockley',
#  'Roddy White',
#  'Jonathan Babineaux',
#  'Jordan Beck',
#  'Chauncey Davis',
#  'Michael Boley',
#  'Frank Omiyale',
#  'DeAndra Cobb',
#  'Darrell Shropshire',
#  'DeAngelo Hall',
#  'Michael Jenkins',
#  'Matt Schaub',
#  'Demorrio Williams',
#  'Chad Lavalais',
#  'Etric Pruitt',
#  'Quincy Wilson',
#  'Bryan Scott',
#  'Justin Griffith',
#  'Jon Olinger',
#  'LaTarence Dunbar',
#  'Waine Bacon',
#  'Demetrin Veal',
#  'T.J. Duckett',
#  'Will Overstreet',
#  'Martin Bibla',
#  'Kevin McCadam',
#  'Kurt Kittner',
#  'Kahlil Hill',
#  'Michael Coleman',
#  'Kevin Shaffer',
#  'Michael Vick',
#  'Alge Crumpler',
#  'Roberto Garza',
#  'Matt Stewart',
#  'Vinny Sutherland',
#  'Randy Garner',
#  'Corey Hall',
#  'Kynan Forney',
#  'Ronald Flemons',
#  'Quentin McCord',
#  'Travis Claridge',
#  'Mark Simoneau',
#  'Michael Thompson',
#  'Anthony Midget',
#  'Mareno Philyaw',
#  'Darrick Vaughn',
#  'Patrick Kerney',
#  'Reggie Kelly',
#  'Jeff Paulk',
#  'Johndale Carty',
#  'Eugene Baker',
#  'Jeff Kelly',
#  'Eric Thigpen',
#  'Todd McClure',
#  'Rondel Menendez',
#  'Keith Brooking',
#  'Bob Hallen',
#  'Jammi German',
#  'Omar Brown',
#  'Tim Dwight',
#  'Elijah Williams',
#  'Ephraim Salaam',
#  'Ken Oxendine',
#  'Henry Slay',
#  'Michael Booker',
#  'Nathan Davis',
#  'Byron Hanspard',
#  'O.J. Santiago',
#  'Henri Crockett',
#  'Marcus Wimberly',
#  'Calvin Collins',
#  'Tony Graziani',
#  'Chris Bayne',
#  'Shannon Brown',
#  'Richard Huntley',
#  'Juran Bolden',
#  'Gary Bandy',
#  'Craig Sauer',
#  'Ethan Brooks',
#  'Devin Bush Sr.',
#  'Ron Davis',
#  'Lorenzo Styles',
#  'Roell Preston',
#  'Travis Hall',
#  'John Burrough',
#  'Bert Emanuel',
#  'Anthony Phillips',
#  'Alai Kalaniuvalu',
#  'Perry Klein',
#  'Mitch Davis',
#  'Harrison Houston',
#  'Jamal Anderson',
#  'Rashod Bateman',
#  'Odafe Oweh',
#  'Ben Cleveland',
#  'Brandon Stephens',
#  'Tylan Wallace',
#  'Shaun Wade',
#  'Daelin Hayes',
#  'Ben Mason',
#  'Patrick Queen',
#  'J.K. Dobbins',
#  'Justin Madubuike',
#  'Devin Duvernay',
#  'Malik Harrison',
#  'Tyre Phillips',
#  'Ben Bredeson',
#  'Broderick Washington Jr.',
#  'James Proche',
#  'Geno Stone',
#  'Marquise Brown',
#  'Jaylon Ferguson',
#  'Miles Boykin',
#  'Justice Hill',
#  'Ben Powers',
#  'Iman Marshall',
#  'Daylon Mack',
#  'Trace McSorley',
#  'Hayden Hurst',
#  'Lamar Jackson',
#  'Orlando Brown Jr.',
#  'Mark Andrews',
#  'Anthony Averett',
#  'Kenny Young',
#  'Jaleel Scott',
#  'Jordan Lasley',
#  'DeShon Elliott',
#  'Greg Senat',
#  'Bradley Bozeman',
#  'Zach Sieler',
#  'Marlon Humphrey',
#  'Tyus Bowser',
#  'Chris Wormley',
#  'Tim Williams',
#  'Nico Siragusa',
#  'Jermaine Eluemunor',
#  'Chuck Clark',
#  'Ronnie Stanley',
#  'Kamalei Correa',
#  'Bronson Kaufusi',
#  'Tavon Young',
#  'Chris Moore',
#  'Alex Lewis',
#  'Willie Henry',
#  'Kenneth Dixon',
#  'Matt Judon',
#  'Keenan Reynolds',
#  'Maurice Canady',
#  'Breshad Perriman',
#  'Maxx Williams',
#  'Carl Davis',
#  "Za'Darius Smith",
#  'Javorius Allen',
#  'Tray Walker',
#  'Nick Boyle',
#  'Robert Myers',
#  'Darren Waller',
#  'C.J. Mosley',
#  'Timmy Jernigan',
#  'Terrence Brooks',
#  'Crockett Gillmore',
#  'Brent Urban',
#  'Lorenzo Taliaferro',
#  'John Urschel',
#  'Keith Wenning',
#  'Michael Campanaro',
#  'Matt Elam',
#  'Arthur Brown',
#  'Brandon Williams',
#  'John Simon',
#  'Kyle Juszczyk',
#  'Ricky Wagner',
#  'Kapron Lewis-Moore',
#  'Ryan Jensen',
#  'Aaron Mellette',
#  'Marc Anthony',
#  'Courtney Upshaw',
#  'Kelechi Osemele',
#  'Bernard Pierce',
#  'Gino Gradkowski',
#  'Christian Thompson',
#  'Asa Jackson',
#  'Tommy Streeter',
#  'DeAngelo Tyson',
#  'Jimmy Smith',
#  'Torrey Smith',
#  'Jah Reid',
#  'Tandon Doss',
#  'Chykie Brown',
#  'Pernell McPhee',
#  'Tyrod Taylor',
#  'Anthony Allen',
#  'Sergio Kindle',
#  'Terrence Cody',
#  'Ed Dickson',
#  'Dennis Pitta',
#  'David Reed',
#  'Arthur Jones',
#  'Ramon Harewood',
#  'Michael Oher',
#  'Paul Kruger',
#  'Lardarius Webb',
#  'Jason Phillips',
#  'Davon Drew',
#  'Cedric Peerman',
#  'Joe Flacco',
#  'Ray Rice',
#  'Tavares Gooden',
#  'Tom Zbikowski',
#  'Oniel Cousins',
#  'Marcus Smith',
#  'David Hale',
#  'Haruki Nakamura',
#  'Justin Harper',
#  'Allen Patrick',
#  'Ben Grubbs',
#  'Yamon Figurs',
#  'Marshal Yanda',
#  'Antwan Barnes',
#  "Le'Ron McClain",
#  'Troy Smith',
#  'Prescott Burgess',
#  'Haloti Ngata',
#  'Chris Chester',
#  'David Pittman',
#  'Demetrius Williams',
#  'P.J. Daniels',
#  'Dawan Landry',
#  'Quinn Sypniewski',
#  'Sam Koch',
#  'Derrick Martin',
#  'Ryan LaCasse',
#  'Mark Clayton',
#  'Dan Cody',
#  'Adam Terry',
#  'Jason Brown',
#  'Justin Green',
#  'Derek Anderson',
#  'Mike Smith',
#  'Dwan Edwards',
#  'Devard Darling',
#  'Roderick Green',
#  'Josh Harris',
#  'Clarence Moore',
#  'Derek Abney',
#  'Brian Rimpf',
#  'Terrell Suggs',
#  'Kyle Boller',
#  'Musa Smith',
#  'Jarret Johnson',
#  'Ovie Mughelli',
#  'Aubrayo Franklin',
#  'Tony Pashos',
#  'Gerome Sapp',
#  'Trent Smith',
#  'Mike Mabry',
#  'Antwoine Sanders',
#  'Ed Reed HOF',
#  'Anthony Weaver',
#  'Dave Zastudil',
#  'Ron Johnson',
#  'Terry Jones',
#  'Lamont Brightful',
#  'Javin Hunter',
#  'Chester Taylor',
#  'Chad Williams',
#  'Wes Pate',
#  'Todd Heap',
#  'Gary Baxter',
#  'Casey Rabach',
#  'Ed Hartwell',
#  'Chris Barnes',
#  'Joe Maese',
#  'Dwayne Missouri',
#  'Jamal Lewis',
#  'Travis Taylor',
#  'Chris Redman',
#  'Richard Mercier',
#  'Adalius Thomas',
#  'Cedric Woodard',
#  'Chris McAlister',
#  'Brandon Stokley',
#  'Edwin Mulitalo',
#  'Anthony Poindexter',
#  'Duane Starks',
#  'Patrick Johnson',
#  'Martin Chase',
#  'Ryan Sutter',
#  'Ron Rogers',
#  'Sammy Williams',
#  'Cam Quayle',
#  'Peter Boulware',
#  'Jamie Sharper',
#  'Kim Herring',
#  'Jay Graham',
#  'Tyrus McCloud',
#  'Jeff Mitchell',
#  'Steve Lee',
#  'Cornell Brown',
#  'Chris Ward',
#  'Wally Richardson',
#  'Ralph Staten',
#  'Leland Taylor',
#  'Jonathan Ogden HOF',
#  'Ray Lewis HOF',
#  'DeRon Jenkins',
#  'Jermaine Lewis',
#  'Dexter Daniels',
#  'James Roe',
#  'Jon Stark',
#  'Gregory Rousseau',
#  'Carlos Basham',
#  'Spencer Brown',
#  'Tommy Doyle',
#  'Marquez Stevenson',
#  'Damar Hamlin',
#  'Rachad Wildgoose',
#  'Jack Anderson',
#  'A.J. Epenesa',
#  'Zack Moss',
#  'Gabriel Davis',
#  'Jake Fromm',
#  'Tyler Bass',
#  'Isaiah Hodgins',
#  'Dane Jackson',
#  'Ed Oliver',
#  'Cody Ford',
#  'Devin Singletary',
#  'Dawson Knox',
#  'Vosean Joseph',
#  'Jaquan Johnson',
#  'Darryl Johnson',
#  'Tommy Sweeney',
#  'Josh Allen',
#  'Tremaine Edmunds',
#  'Harrison Phillips',
#  'Taron Johnson',
#  'Siran Neal',
#  'Wyatt Teller',
#  'Ray-Ray McCloud',
#  'Austin Proehl',
#  "Tre'Davious White",
#  'Zay Jones',
#  'Dion Dawkins',
#  'Matt Milano',
#  'Nathan Peterman',
#  'Tanner Vallejo',
#  'Shaq Lawson',
#  'Reggie Ragland',
#  'Adolphus Washington',
#  'Cardale Jones',
#  'Jonathan Williams',
#  'Kolby Listenbee',
#  'Kevon Seymour',
#  'Ronald Darby',
#  'John Miller',
#  'Karlos Williams',
#  'Tony Steward',
#  "Nick O'Leary",
#  'Dezmin Lewis',
#  'Sammy Watkins',
#  'Cyrus Kouandjio',
#  'Preston Brown',
#  'Ross Cockrell',
#  'Cyril Richardson',
#  'Randell Johnson',
#  'Seantrel Henderson',
#  'EJ Manuel',
#  'Robert Woods',
#  'Kiko Alonso',
#  'Marquise Goodwin',
#  'Duke Williams',
#  'Jonathan Meeks',
#  'Dustin Hopkins',
#  'Chris Gragg',
#  'Stephon Gilmore',
#  'Cordy Glenn',
#  'T.J. Graham',
#  'Nigel Bradham',
#  'Ron Brooks',
#  'Zebrie Sanders',
#  'Tank Carder',
#  'Mark Asper',
#  'John Potter',
#  'Marcell Dareus',
#  'Aaron Williams',
#  'Kelvin Sheppard',
#  "Da'Norris Searcy",
#  'Chris Hairston',
#  'Johnny White',
#  'Chris White',
#  'Justin Rogers',
#  'Michael Jasper',
#  'C.J. Spiller',
#  'Torell Troup',
#  'Alex Carrington',
#  'Marcus Easley',
#  'Ed Wang',
#  'Arthur Moats',
#  'Danny Batten',
#  'Levi Brown',
#  'Kyle Calloway',
#  'Aaron Maybin',
#  'Eric Wood',
#  'Jairus Byrd',
#  'Andy Levitre',
#  'Shawn Nelson',
#  'Nic Harris',
#  'Cary Harris',
#  'Ellis Lankster',
#  'Leodis McKelvin',
#  'James Hardy',
#  'Chris Ellis',
#  'Reggie Corner',
#  'Derek Fine',
#  'Alvin Bowen',
#  'Xavier Omon',
#  'Demetress Bell',
#  'Steve Johnson',
#  'Kennard Cox',
#  'Marshawn Lynch',
#  'Paul Posluszny',
#  'Trent Edwards',
#  'Dwayne Wright',
#  'John Wendling',
#  'Derek Schouman',
#  'C.J. Ah You',
#  'Donte Whitner',
#  'John McCargo',
#  'Ashton Youboty',
#  'Ko Simpson',
#  'Kyle Williams',
#  'Brad Butler',
#  'Keith Ellison',
#  'Terrance Pennington',
#  'Aaron Merz',
#  'Roscoe Parrish',
#  'Kevin Everett',
#  'Duke Preston',
#  'Eric King',
#  'Justin Geisinger',
#  'Lionel Gates',
#  'Lee Evans',
#  'J.P. Losman',
#  'Tim Anderson',
#  'Tim Euhus',
#  'Dylan McFarland',
#  'Jonathan Smith',
#  'Willis McGahee',
#  'Chris Kelsay',
#  'Angelo Crowell',
#  'Terrence McGee',
#  'Sam Aiken',
#  'Ben Sobieski',
#  'Lauvale Sape',
#  'Mario Haggan',
#  'Mike Williams',
#  'Josh Reed',
#  'Ryan Denney',
#  'Coy Wire',
#  'Justin Bannan',
#  'Kevin Thomas',
#  'Mike Pucillo',
#  'Rodney Wright',
#  'Jarrett Ferguson',
#  'Dominique Stevenson',
#  'Nate Clements',
#  'Aaron Schobel',
#  'Travis Henry',
#  'Ron Edwards',
#  'Jonas Jennings',
#  'Brandon Spoon',
#  'Marques Sullivan',
#  'Tony Driver',
#  "Dan O'Leary",
#  'Jimmy Williams',
#  'Reggie Germany',
#  'Tyrone Robertson',
#  'Erik Flowers',
#  'Travares Tillman',
#  'Corey Moore',
#  'Avion Black',
#  'Sammy Morris',
#  'Leif Larsen',
#  'Drew Haddad',
#  'DaShon Polk',
#  'Antoine Winfield',
#  'Peerless Price',
#  'Shawn Bryson',
#  'Keith Newman',
#  'Bobby Collins',
#  'Jay Foreman',
#  'Armon Hatcher',
#  'Sheldon Jackson',
#  'Bryce Fisher',
#  'Sam Cowart',
#  'Robert Hicks',
#  'Jonathan Linton',
#  'Fred Coleman',
#  'Victor Allotey',
#  'Kamil Loud',
#  'Antowain Smith',
#  'Marcellus Wiley',
#  'Jamie Nails',
#  'Sean Woodson',
#  'Marcus Spriggs',
#  'Pat Fitzgerald',
#  'Eric Moulds',
#  'Gabe Northern',
#  'Matt Stevens',
#  'Sean Moran',
#  'Raymond Jackson',
#  'Leon Neal',
#  'Dusty Zeigler',
#  'Dan Brandenburg',
#  'Jay Riemersma',
#  'Eric Smedley',
#  'Ruben Brown',
#  'Todd Collins',
#  'Marlon Kerner',
#  'Damien Covington',
#  'Ken Irvin',
#  'Justin Armour',
#  'Tony Cline',
#  'John Holecek',
#  'Shannon Clavelle',
#  'Tom Nutten',
#  'Darick Holmes',
#  'Jeff Burris',
#  'Bucky Brooks',
#  'Lonnie Johnson',
#  'Sam Rogers',
#  'Marlo Perry',
#  'Corey Louchiey',
#  'Sean Crocker',
#  'A.J. Ofodile',
#  'Anthony Abrams',
#  'Kevin Knox',
#  'Filmel Johnson',
#  'Jaycee Horn',
#  'Terrace Marshall Jr.',
#  'Brady Christensen',
#  'Tommy Tremble',
#  'Chuba Hubbard',
#  'Daviyon Nixon',
#  'Keith Taylor',
#  'Deonte Brown',
#  'Shi Smith',
#  'Thomas Fletcher',
#  'Phil Hoskins',
#  'Derrick Brown',
#  'Yetur Gross-Matos',
#  'Jeremy Chinn',
#  'Troy Pride Jr.',
#  'Kenny Robinson Jr.',
#  'Bravvion Roy',
#  'Stantley Thomas-Oliver',
#  'Brian Burns',
#  'Greg Little',
#  'Will Grier',
#  'Christian Miller',
#  'Jordan Scarlett',
#  'Dennis Daley',
#  'Terry Godwin',
#  'D.J. Moore',
#  'Donte Jackson',
#  'Rashaan Gaulden',
#  'Ian Thomas',
#  'Marquis Haynes',
#  'Jermaine Carter Jr.',
#  'Andre Smith',
#  'Kendrick Norton',
#  'Christian McCaffrey',
#  'Curtis Samuel',
#  'Taylor Moton',
#  'Daeshon Hall',
#  'Corn Elder',
#  'Alex Armah',
#  'Harrison Butker',
#  'Vernon Butler',
#  'James Bradberry',
#  'Daryl Worley',
#  'Zack Sanchez',
#  'Beau Sandland',
#  'Shaq Thompson',
#  'Devin Funchess',
#  'Daryl Williams',
#  'David Mayo',
#  'Cameron Artis-Payne',
#  'Kelvin Benjamin',
#  'Kony Ealy',
#  'Trai Turner',
#  'Tre Boston',
#  'Bene Benwikere',
#  'Tyler Gaffney',
#  'Star Lotulelei',
#  'Kawann Short',
#  'Edmund Kugbila',
#  'A.J. Klein',
#  'Kenjon Barner',
#  'Luke Kuechly',
#  'Amini Silatolu',
#  'Frank Alexander',
#  'Joe Adams',
#  'Josh Norman',
#  'Brad Nortman',
#  'D.J. Campbell',
#  'Cam Newton',
#  'Terrell McClain',
#  'Sione Fua',
#  'Brandon Hogan',
#  'Kealoha Pilares',
#  'Lawrence Wilson',
#  'Zachary Williams',
#  'Lee Ziemba',
#  'Jimmy Clausen',
#  'Brandon LaFell',
#  'Armanti Edwards',
#  'Eric Norwood',
#  'Greg Hardy',
#  'David Gettis',
#  'Jordan Pugh',
#  'Tony Pike',
#  'R.J. Stanford',
#  'Robert McClain',
#  'Everette Brown',
#  'Sherrod Martin',
#  'Corvey Irvin',
#  'Mike Goodson',
#  'Tony Fiammetta',
#  'Duke Robinson',
#  'Captain Munnerlyn',
#  'Jonathan Stewart',
#  'Jeff Otah',
#  'Charles Godfrey',
#  'Dan Connor',
#  'Gary Barnidge',
#  'Nick Hayden',
#  'Hilee Taylor',
#  'Geoff Schwartz',
#  'Mackenzy Bernadeau',
#  'Jon Beason',
#  'Dwayne Jarrett',
#  'Ryan Kalil',
#  'Charles Johnson',
#  'Ryne Robinson',
#  'Dante Rosario',
#  'Tim Shaw',
#  'C.J. Wilson',
#  'DeAngelo Williams',
#  'Richard Marshall',
#  'James Anderson',
#  'Rashad Butler',
#  'Nate Salley',
#  'Jeff King',
#  'Will Montgomery',
#  'Stanley McClover',
#  'Thomas Davis',
#  'Eric Shelton',
#  'Evan Mathis',
#  'Atiyyah Ellison',
#  'Stefan Lefors',
#  'Adam Seward',
#  'Geoff Hangartner',
#  ...]

# %%
# %%time

i = 0
j = 0
qb = 0

for player_url in url_list:
    
    if len(str(player_url)) > 4:
    
        if i == 0:
        
            
            try:    
                df2 = pd.read_html(player_url)
                df3 = df2[1]
                df3['name'] = names[i]
                i += 1
            except:
                i += 1
                
    
        else:
        
            
            try:
                player_df = pd.read_html(player_url)
                
                for table in player_df:
                    av = 'blank'
                    
                    if 'AV' in table.columns:
                                
                        if qb == 0:
                            qbdf = table
                            qbdf['name'] = names[i]
                            qb += 1
                            
                        else:
                            table['name'] = names[i]
                            qbdf = qbdf.append(table)
                            qb += 1
                            break
                    
                    else:
                        for column in table:
                       
                            if len(column) > 1:
                                if 'AV' in column[1]:
                                    av = column
                
                                elif 'Year' in column[1]:
                                    year = column
                
                                elif 'Tm' in column[1]:
                                    team = column
                
                                elif 'Age' in column[1]:
                                    age = column
                                    
                                elif 'Pos' in column[1]:
                                    pos = column
                                    
                                
                        if av != 'blank':
                            table1 = table[[year, age, pos, team, av]]
                            table1['name'] = names[i]
                            df3 = df3.append(table1)
                            break
                        
                i += 1
                    
            except:
                i += 1
                    
                
    else:
        
        i += 1
# Out:
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 7min 58s, sys: 27.9 s, total: 8min 26s
# Wall time: 25min 29s

# %%
df3
# Out:
#    Def Interceptions                     Fumbles                  ...  \
#                  Int  Lng   PD   TD  Yds      FF  FR Fmb  TD Yds  ...
# 0                0.0  0.0  2.0  0.0  0.0     NaN NaN NaN NaN NaN  ...
# 1                0.0  0.0  2.0  0.0  0.0     NaN NaN NaN NaN NaN  ...
# 0                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# 1                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# 0                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# ..               ...  ...  ...  ...  ...     ...  ..  ..  ..  ..  ...
# 2                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# 3                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# 4                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# 5                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
# 6                NaN  NaN  NaN  NaN  NaN     NaN NaN NaN NaN NaN  ...
#
#    Unnamed: 1_level_0 Unnamed: 22_level_0 Unnamed: 23_level_0  \
#                   Age                  AV                Sfty
# 0                  22                 NaN                 NaN
# 1              Career                 NaN                 NaN
# 0                  21                 NaN                 NaN
# 1              Career                 NaN                 NaN
# 0                  22                 NaN                 NaN
# ..                ...                 ...                 ...
# 2                  26                 3.0                 NaN
# 3                  27                 0.0                 NaN
# 4              Career                 7.0                 NaN
# 5               3 yrs                 7.0                 NaN
# 6                1 yr                 0.0                 NaN
#
#    Unnamed: 24_level_0 Unnamed: 2_level_0 Unnamed: 31_level_0  \
#                     AV                 Tm                  AV
# 0                  NaN                ARI                 NaN
# 1                  NaN                NaN                 NaN
# 0                  NaN                ARI                 NaN
# 1                  NaN                NaN                 NaN
# 0                  NaN                ARI                 NaN
# ..                 ...                ...                 ...
# 2                  NaN                WAS                 NaN
# 3                  NaN                KAN                 NaN
# 4                  NaN                NaN                 NaN
# 5                  NaN                WAS                 NaN
# 6                  NaN                KAN                 NaN
#
#    Unnamed: 34_level_0 Unnamed: 3_level_0 Unnamed: 4_level_0            name
#                     AV                Pos                No.
# 0                  NaN                 lb               25.0   Zaven Collins
# 1                  NaN                NaN                NaN   Zaven Collins
# 0                  NaN                 wr                NaN   Rondale Moore
# 1                  NaN                NaN                NaN   Rondale Moore
# 0                  NaN                 cb                NaN    Marco Wilson
# ..                 ...                ...                ...             ...
# 2                  NaN                NaN                NaN  Dexter Nottage
# 3                  NaN                NaN                NaN  Dexter Nottage
# 4                  NaN                NaN                NaN  Dexter Nottage
# 5                  NaN                NaN                NaN  Dexter Nottage
# 6                  NaN                NaN                NaN  Dexter Nottage
#
# [45322 rows x 30 columns]

# %%
qbdf
# Out:
#       Year     Age   Tm  Pos   No.   G   GS   AV           name  QBrec  ...  \
# 0     2021      24  ARI  NaN  38.0   3  0.0  NaN  James Wiggins    NaN  ...
# 1   Career  Career  NaN  NaN   NaN   3  NaN  NaN  James Wiggins    NaN  ...
# 0     2020      23  ARI  NaN  79.0  13  0.0  1.0     Josh Jones    NaN  ...
# 1     2021      24  ARI   ol  79.0  10  9.0  NaN     Josh Jones    NaN  ...
# 2   Career  Career  NaN  NaN   NaN  23  9.0  1.0     Josh Jones    NaN  ...
# ..     ...     ...  ...  ...   ...  ..  ...  ...            ...    ...  ...
# 18   2 yrs   2 yrs  DEN  NaN   NaN  14    7    8   Gus Frerotte  4-3-0  ...
# 19   2 yrs   2 yrs  STL  NaN   NaN   9    3   -2   Gus Frerotte  1-2-0  ...
# 20    1 yr    1 yr  CIN  NaN   NaN   4    3    1   Gus Frerotte  0-3-0  ...
# 21    1 yr    1 yr  DET  NaN   NaN   9    6    7   Gus Frerotte  2-4-0  ...
# 22    1 yr    1 yr  MIA  NaN   NaN  16   15    9   Gus Frerotte  9-6-0  ...
#
#       Y/G  Rate  QBR   Sk Yds.1   Sk%  NY/A ANY/A  4QC  GWD
# 0     NaN   NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 1     NaN   NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 0     NaN   NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 1     NaN   NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 2     NaN   NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# ..    ...   ...  ...  ...   ...   ...   ...   ...  ...  ...
# 18  148.9  85.5  NaN   15    98   5.1  6.73  6.33  2.0  2.0
# 19  115.7  58.5  NaN   11    59   6.1  5.43  3.22  NaN  NaN
# 20  109.3  46.1  NaN   10    74  10.5  3.82  1.66  NaN  NaN
# 21  235.2  83.6  NaN   28   202   8.9  6.06  5.63  2.0  2.0
# 22  187.3  71.9  NaN   26   158   5.0  5.46  5.03  0.0  1.0
#
# [4739 rows x 33 columns]

# %%
df3.to_excel('player_data_nonQB.xlsx')
qbdf.to_excel('player_data_QB.xlsx')

# %%
file = 'team_historical_records.xlsx'
data = pd.read_excel(file)
data
# Out:
#       Year   Lg                 Tm  W   L  T Div. Finish Playoffs   PF   PA  \
# 0     2021  NFL  Arizona Cardinals  7   1  0    1st of 4      NaN  246  138
# 1     2020  NFL  Arizona Cardinals  8   8  0    3rd of 4      NaN  410  367
# 2     2019  NFL  Arizona Cardinals  5  10  1    4th of 4      NaN  361  442
# 3     2018  NFL  Arizona Cardinals  3  13  0    4th of 4      NaN  225  425
# 4     2017  NFL  Arizona Cardinals  8   8  0    3rd of 4      NaN  295  361
# ...    ...  ...                ... ..  .. ..         ...      ...  ...  ...
# 2229  1930  NFL   Brooklyn Dodgers  7   4  1   4th of 11      NaN  154   59
# 2230  1952  NFL      Dallas Texans  1  11  0    6th of 6      NaN  182  427
# 2231  1951  NFL     New York Yanks  1   9  2    6th of 6      NaN  241  382
# 2232  1950  NFL     New York Yanks  7   5  0    3rd of 7      NaN  366  367
# 2233  1949  NFL  New York Bulldogs  1  10  1    5th of 5      NaN  153  368
#
#       ... Yds.1 T/G Pts± Yds± out of    MoV   SoS    SRS  OSRS  DSRS
# 0     ...     4   7    2    5     32   13.5  -0.3   13.2   6.2   7.0
# 1     ...    13  17   13   11     32    2.7  -0.1    2.6   1.5   1.0
# 2     ...    32  18   23   29     32   -5.1   1.8   -3.2  -0.3  -2.9
# 3     ...    20  29   32   32     32  -12.5   1.0  -11.5  -9.6  -1.9
# 4     ...     6  23   24   15     32   -4.1   0.4   -3.7  -4.0   0.2
# ...   ...   ...  ..  ...  ...    ...    ...   ...    ...   ...   ...
# 2229  ...     1   1    3    1     11    7.9  -2.1    5.8   1.4   4.4
# 2230  ...    12  11   12   12     12  -20.4   2.4    -18    -6   -12
# 2231  ...    12   7   12   12     12  -11.8   2.3   -9.4  -0.9  -8.5
# 2232  ...    12   4    7   11     13   -0.1  -3.5   -3.6   5.4  -8.9
# 2233  ...     9  10    9   10     10  -17.9   1.3  -16.6    -9  -7.5
#
# [2234 rows x 29 columns]

# %%
data = data[data.Year.isnull()==False]
data
# Out:
#       Year   Lg                 Tm  W   L  T Div. Finish Playoffs   PF   PA  \
# 0     2021  NFL  Arizona Cardinals  7   1  0    1st of 4      NaN  246  138
# 1     2020  NFL  Arizona Cardinals  8   8  0    3rd of 4      NaN  410  367
# 2     2019  NFL  Arizona Cardinals  5  10  1    4th of 4      NaN  361  442
# 3     2018  NFL  Arizona Cardinals  3  13  0    4th of 4      NaN  225  425
# 4     2017  NFL  Arizona Cardinals  8   8  0    3rd of 4      NaN  295  361
# ...    ...  ...                ... ..  .. ..         ...      ...  ...  ...
# 2229  1930  NFL   Brooklyn Dodgers  7   4  1   4th of 11      NaN  154   59
# 2230  1952  NFL      Dallas Texans  1  11  0    6th of 6      NaN  182  427
# 2231  1951  NFL     New York Yanks  1   9  2    6th of 6      NaN  241  382
# 2232  1950  NFL     New York Yanks  7   5  0    3rd of 7      NaN  366  367
# 2233  1949  NFL  New York Bulldogs  1  10  1    5th of 5      NaN  153  368
#
#       ... Yds.1 T/G Pts± Yds± out of    MoV   SoS    SRS  OSRS  DSRS
# 0     ...     4   7    2    5     32   13.5  -0.3   13.2   6.2   7.0
# 1     ...    13  17   13   11     32    2.7  -0.1    2.6   1.5   1.0
# 2     ...    32  18   23   29     32   -5.1   1.8   -3.2  -0.3  -2.9
# 3     ...    20  29   32   32     32  -12.5   1.0  -11.5  -9.6  -1.9
# 4     ...     6  23   24   15     32   -4.1   0.4   -3.7  -4.0   0.2
# ...   ...   ...  ..  ...  ...    ...    ...   ...    ...   ...   ...
# 2229  ...     1   1    3    1     11    7.9  -2.1    5.8   1.4   4.4
# 2230  ...    12  11   12   12     12  -20.4   2.4    -18    -6   -12
# 2231  ...    12   7   12   12     12  -11.8   2.3   -9.4  -0.9  -8.5
# 2232  ...    12   4    7   11     13   -0.1  -3.5   -3.6   5.4  -8.9
# 2233  ...     9  10    9   10     10  -17.9   1.3  -16.6    -9  -7.5
#
# [2178 rows x 29 columns]

# %%
data = data[data.Year != 'Year']
data
# Out:
#       Year   Lg                 Tm  W   L  T Div. Finish Playoffs   PF   PA  \
# 0     2021  NFL  Arizona Cardinals  7   1  0    1st of 4      NaN  246  138
# 1     2020  NFL  Arizona Cardinals  8   8  0    3rd of 4      NaN  410  367
# 2     2019  NFL  Arizona Cardinals  5  10  1    4th of 4      NaN  361  442
# 3     2018  NFL  Arizona Cardinals  3  13  0    4th of 4      NaN  225  425
# 4     2017  NFL  Arizona Cardinals  8   8  0    3rd of 4      NaN  295  361
# ...    ...  ...                ... ..  .. ..         ...      ...  ...  ...
# 2229  1930  NFL   Brooklyn Dodgers  7   4  1   4th of 11      NaN  154   59
# 2230  1952  NFL      Dallas Texans  1  11  0    6th of 6      NaN  182  427
# 2231  1951  NFL     New York Yanks  1   9  2    6th of 6      NaN  241  382
# 2232  1950  NFL     New York Yanks  7   5  0    3rd of 7      NaN  366  367
# 2233  1949  NFL  New York Bulldogs  1  10  1    5th of 5      NaN  153  368
#
#       ... Yds.1 T/G Pts± Yds± out of    MoV   SoS    SRS  OSRS  DSRS
# 0     ...     4   7    2    5     32   13.5  -0.3   13.2   6.2   7.0
# 1     ...    13  17   13   11     32    2.7  -0.1    2.6   1.5   1.0
# 2     ...    32  18   23   29     32   -5.1   1.8   -3.2  -0.3  -2.9
# 3     ...    20  29   32   32     32  -12.5   1.0  -11.5  -9.6  -1.9
# 4     ...     6  23   24   15     32   -4.1   0.4   -3.7  -4.0   0.2
# ...   ...   ...  ..  ...  ...    ...    ...   ...    ...   ...   ...
# 2229  ...     1   1    3    1     11    7.9  -2.1    5.8   1.4   4.4
# 2230  ...    12  11   12   12     12  -20.4   2.4    -18    -6   -12
# 2231  ...    12   7   12   12     12  -11.8   2.3   -9.4  -0.9  -8.5
# 2232  ...    12   4    7   11     13   -0.1  -3.5   -3.6   5.4  -8.9
# 2233  ...     9  10    9   10     10  -17.9   1.3  -16.6    -9  -7.5
#
# [2122 rows x 29 columns]

# %%
data['Year'] = pd.to_numeric(data.Year)
# Out:
# <ipython-input-82-67ab08605119>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'] = pd.to_numeric(data.Year)

# %%
data = data[data.Year > 1993]
data
# Out:
#       Year   Lg                    Tm   W   L  T Div. Finish  Playoffs   PF  \
# 0     2021  NFL     Arizona Cardinals   7   1  0    1st of 4       NaN  246
# 1     2020  NFL     Arizona Cardinals   8   8  0    3rd of 4       NaN  410
# 2     2019  NFL     Arizona Cardinals   5  10  1    4th of 4       NaN  361
# 3     2018  NFL     Arizona Cardinals   3  13  0    4th of 4       NaN  225
# 4     2017  NFL     Arizona Cardinals   8   8  0    3rd of 4       NaN  295
# ...    ...  ...                   ...  ..  .. ..         ...       ...  ...
# 2132  1999  NFL  Washington Redskins*  10   6  0    1st of 5  Lost Div  443
# 2133  1998  NFL   Washington Redskins   6  10  0    4th of 5       NaN  319
# 2134  1997  NFL   Washington Redskins   8   7  1    2nd of 5       NaN  327
# 2135  1996  NFL   Washington Redskins   9   7  0    3rd of 5       NaN  364
# 2136  1995  NFL   Washington Redskins   6  10  0    3rd of 5       NaN  326
#
#        PA  ... Yds.1 T/G Pts± Yds± out of    MoV   SoS    SRS  OSRS  DSRS
# 0     138  ...     4   7    2    5     32   13.5  -0.3   13.2   6.2   7.0
# 1     367  ...    13  17   13   11     32    2.7  -0.1    2.6   1.5   1.0
# 2     442  ...    32  18   23   29     32   -5.1   1.8   -3.2  -0.3  -2.9
# 3     425  ...    20  29   32   32     32  -12.5   1.0  -11.5  -9.6  -1.9
# 4     361  ...     6  23   24   15     32   -4.1   0.4   -3.7  -4.0   0.2
# ...   ...  ...   ...  ..  ...  ...    ...    ...   ...    ...   ...   ...
# 2132  377  ...    30   4    8   11     31    4.1  -1.3    2.9   6.8  -3.9
# 2133  421  ...    24  24   27   19     30   -6.4  -1.1   -7.5  -1.5  -6.0
# 2134  289  ...    16  14   11   13     30    2.4  -1.1    1.3  -0.6   1.8
# 2135  312  ...    28   4    8   23     30    3.3  -1.4    1.8   2.3  -0.4
# 2136  359  ...    18   6   21   18     30   -2.1   0.1   -1.9  -0.8  -1.2
#
# [853 rows x 29 columns]

# %%
data['W'] = pd.to_numeric(data.W)
data['L'] = pd.to_numeric(data.L)
# Out:
# <ipython-input-90-2b9d20178b46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['W'] = pd.to_numeric(data.W)
# <ipython-input-90-2b9d20178b46>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['L'] = pd.to_numeric(data.L)

# %%
data.to_excel('team_historical_records.xlsx')

# %% [markdown]
# ### Check for Player Positions

# %%
file = 'Draft_history_Football-links.xlsx'
filedf = pd.read_excel(file,sheet_name='draft')
file_list = filedf.values.tolist()

# %%
#iterate over each team, collect their team success chart, and append it into one dataframe
i = 0
for team_url in file_list:
    
    if i == 0:
        
        df1 = pd.read_html(team_url[0])
        df = df1[0]
        i += 1
    
    else:
        
        team_df = pd.read_html(team_url[0])
        df = df.append(team_df[0]) 
        i += 1

# %%
df.to_excel('player_draft_day_data.xlsx')
